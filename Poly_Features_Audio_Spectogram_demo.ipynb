# %%
 import librosa
import matplotlib.pyplot as plt
import numpy as np
import librosa.display

# %%
path = "sound3.wav"
y, sr = librosa.load(path)
S = np.abs(librosa.stft(y))
p2 = librosa.feature.poly_features(S=S, order=2)
p1 = librosa.feature.poly_features(S=S, order=1)
p0 = librosa.feature.poly_features(S=S, order=0)

plt.figure(figsize=(8, 8))
ax = plt.subplot(4,1,1)
plt.plot(p2[2], label='order=2', alpha=0.8)
plt.plot(p1[1], label='order=1', alpha=0.8)
plt.plot(p0[0], label='order=0', alpha=0.8)
plt.xticks([])
plt.ylabel('Constant')
plt.legend()
plt.subplot(4,1,2, sharex=ax)
plt.plot(p2[1], label='order=2', alpha=0.8)
plt.plot(p1[0], label='order=1', alpha=0.8)
plt.xticks([])
plt.ylabel('Linear')
plt.subplot(4,1,3, sharex=ax)
plt.plot(p2[0], label='order=2', alpha=0.8)
plt.xticks([])
plt.ylabel('Quadratic')
plt.subplot(4,1,4, sharex=ax)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max),y_axis='log')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-226817dde78f> in <module>()
#       1 path = "sound3.wav"
# ----> 2 y, sr = librosa.load(path)
#       3 S = np.abs(librosa.stft(y))
#       4 p2 = librosa.feature.poly_features(S=S, order=2)
#       5 p1 = librosa.feature.poly_features(S=S, order=1)
#
# /usr/local/lib/python3.6/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     160
#     161         if n_channels > 1:
# --> 162             y = y.reshape((-1, n_channels)).T
#     163             if mono:
#     164                 y = to_mono(y)
#
# ValueError: cannot reshape array of size 2097113 into shape (2)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path = "bathroom_exhaust_fan.wav"

def spectogram_generate(path=path):
  y, sr = librosa.load(path)
  plt.figure(figsize=(20, 8))
  D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
  librosa.display.specshow(D, y_axis='linear')
  plt.colorbar(format='%+2.0f dB')
  plt.title(f'Tap Water Audio Spectogram')
  plt.show()

# %%
import matplotlib.pyplot as plt
y, sr = librosa.load(path)
S = np.abs(librosa.stft(y))
p0 = librosa.feature.poly_features(S=S, order=0)
p1 = librosa.feature.poly_features(S=S, order=1)
p2 = librosa.feature.poly_features(S=S, order=2)
plt.figure(figsize=(8, 8))
ax = plt.subplot(4,1,1)
plt.plot(p2[2], label='order=2', alpha=0.8)
plt.plot(p1[1], label='order=1', alpha=0.8)
plt.plot(p0[0], label='order=0', alpha=0.8)
plt.xticks([])
plt.ylabel('Constant')
plt.legend()
plt.subplot(4,1,2, sharex=ax)
plt.plot(p2[1], label='order=2', alpha=0.8)
plt.plot(p1[0], label='order=1', alpha=0.8)
plt.xticks([])
plt.ylabel('Linear')
plt.subplot(4,1,3, sharex=ax)
plt.plot(p2[0], label='order=2', alpha=0.8)
plt.xticks([])
plt.ylabel('Quadratic')
plt.subplot(4,1,4, sharex=ax)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log')
plt.tight_layout()
plt.show()

# %%
path2 = "wooden_door_close_close.wav"
def spectogram_generate(path=path):
  y, sr = librosa.load(path)
  plt.figure(figsize=(20, 8))
  D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
  librosa.display.specshow(D, y_axis='linear')
  plt.colorbar(format='%+2.0f dB')
  plt.title(f'Wooden Door Close Audio Spectogram')
  plt.show()
spectogram_generate(path1)

path4 = "metal_door_close.wav"
def spectogram_generate(path=path):
  y, sr = librosa.load(path)
  plt.figure(figsize=(20, 8))
  D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
  librosa.display.specshow(D, y_axis='linear')
  plt.colorbar(format='%+2.0f dB')
  plt.title(f'Wooden Door Opening Audio Spectogram')
  plt.show()
spectogram_generate(path4)


path5 = "metal_door_open.wav"
def spectogram_generate(path=path):
  y, sr = librosa.load(path)
  plt.figure(figsize=(20, 8))
  D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
  librosa.display.specshow(D, y_axis='linear')
  plt.colorbar(format='%+2.0f dB')
  plt.title(f'Metal Door Opening Audio Spectogram')
  plt.show()
spectogram_generate(path5)

# %%
spectogram_generate(path)

# %%
path1 = "Fan_noise.wav"
def spectogram_generate(path=path):
  y, sr = librosa.load(path)
  plt.figure(figsize=(20, 8))
  D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
  librosa.display.specshow(D, y_axis='linear')
  plt.colorbar(format='%+2.0f dB')
  plt.title(f'Tap Water Audio Spectogram')
  plt.show()
spectogram_generate(path1)
